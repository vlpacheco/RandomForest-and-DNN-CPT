# %%
"""
Global Feature Selection 
    - X = 'Depth (m)','iso_classes_encoded', 'Oberhollenzer_classes', 
    'σ,v (kPa)', 'σ',v (kPa)'.
    
    - Y = 'qc (MPa)','fs (kPa)'.
"""
#General Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, CSVLogger
from sklearn.model_selection import train_test_split
import time

'''
PreProcessing
''' 
#Loading Database
df_cpt=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Target_Encoded_Database.csv')

#Transforming to DataFrame
df_cpt = pd.DataFrame(df_cpt)
df_cpt = df_cpt.drop(columns='Unnamed: 0')

#Dropping zeros from qc
df_cpt = df_cpt[~(df_cpt[['qc (MPa)']] == 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['qc (MPa)']] < 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['SBT (-)']] == 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['SBTn (-)']] == 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['Mod. SBTn (-)']] == 0).any(axis = 1)]

#Transforming to NumpyArray
df_cpt = df_cpt.to_numpy()

'''
Inputs
'''
X = df_cpt[:, [17, 18, 19]]

#1--> D'Depth (m)' --> index: 1
#2 --> 'σ,v (kPa)' --> index: 9
#3 --> "σ',v (kPa)" --> index: 11
#4 --> 'SBT (-)' --> index: 17
#5 --> 'SBTn (-)' --> index: 18
#6 --> 'Mod. SBTn (-)' --> index: 19 
#7 --> 'Ic (-)' --> index: 21
#8 --> 'Ic SBT (-)' --> index:22 
#9 --> 'Ib (-)' --> index: 23
#10 --> 'Oberhollenzer_classes' --> index: 24
#11 --> 'iso_classes_encoded' --> index: 27

#X=X.to(device) #To GPU

'''
Outputs
'''
y = df_cpt[:, [2, 3]] 

#1 --> 'qc (MPa)' --> index: 2
#2 --> 'fs (kPa)' --> index: 3

#y=y.to(device) #To GPU

#Scaling the and preparing the data
scalerX = MinMaxScaler()
scalerY = MinMaxScaler()

#Scaling the Data
scaledX=scalerX.fit_transform(X)
scaledY=scalerY.fit_transform(y)

#Train & Test split
X_train, X_test, y_train, y_test = train_test_split(scaledX, scaledY, 
                                                   test_size = 0.20)

# %%
'''
Neural Network Structure
'''
#Callbacks
es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, 
                   patience = 30)
csv_logger = CSVLogger('DNN_CPTNet_Colonel_03.csv', 
                       separator = ',', append = False)
model_checkpoint = ModelCheckpoint('DNN_CPTNet_Colonel_03.hdf5', 
                                   monitor = 'val_loss', verbose = 1, save_best_only = True)

#Optimizer
l_r = 0.001
momentum = 0.9
opt_1 = keras.optimizers.Nadam(learning_rate = l_r)
opt_2 = keras.optimizers.SGD(learning_rate = l_r, momentum = momentum)
opt_3 = tf.keras.optimizers.RMSprop(learning_rate = 0.001, rho=0.9, momentum = 0.0, epsilon=1e-07)
opt_4 = keras.optimizers.Adam(learning_rate = l_r)

#Weight Initializer
init_mode_1 = 'he_normal'
init_mode_2 = tf.keras.initializers.LecunNormal()

#Activation functions
trelu = tf.keras.layers.ThresholdedReLU(theta = 1.0)
prelu = tf.keras.layers.PReLU()
leaky_relu = tf.keras.layers.LeakyReLU(alpha = 0.3)

#Model
model = Sequential()

model.add(Dense(21, input_dim = 3,
                activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(2, activation = 'linear', 
                kernel_initializer = init_mode_1))

model.compile(optimizer = opt_1, loss = 'mse', 
              metrics=['mse', 'mae', 'mape'])

#Initial time
start_time = time.time()

#Fitting Network
history =  model.fit(X_train, y_train, epochs = 500, batch_size = 64,
                     validation_split = 0.25, callbacks = [model_checkpoint, csv_logger, es])

#Final time
end_time = (time.time() - start_time)
print('The running time is: %.2f minutes' %(end_time/60))
# Out:
# Epoch 1/500
# 7929/7929 [==============================] - 19s 2ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0258 - mape: 1123.6409 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0215 - val_mape: 644.9438
#
# Epoch 00001: val_loss improved from inf to 0.00199, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 2/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0218 - mape: 1133.7485 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0217 - val_mape: 1722.8845
#
# Epoch 00002: val_loss improved from 0.00199 to 0.00173, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 3/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0212 - mape: 1047.4139 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0227 - val_mape: 1422.1061
#
# Epoch 00003: val_loss did not improve from 0.00173
# Epoch 4/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0211 - mape: 772.3682 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0215 - val_mape: 1361.7111
#
# Epoch 00004: val_loss did not improve from 0.00173
# Epoch 5/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0210 - mape: 949.2604 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0211 - val_mape: 839.9927
#
# Epoch 00005: val_loss did not improve from 0.00173
# Epoch 6/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0209 - mape: 977.6831 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 513.0837
#
# Epoch 00006: val_loss improved from 0.00173 to 0.00172, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 7/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0209 - mape: 875.3269 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0215 - val_mape: 911.3879
#
# Epoch 00007: val_loss did not improve from 0.00172
# Epoch 8/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0209 - mape: 817.6306 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0209 - val_mape: 395.9315
#
# Epoch 00008: val_loss improved from 0.00172 to 0.00171, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 9/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0208 - mape: 945.3939 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0212 - val_mape: 1730.0681
#
# Epoch 00009: val_loss did not improve from 0.00171
# Epoch 10/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0207 - mape: 785.3340 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0213 - val_mape: 1452.8230
#
# Epoch 00010: val_loss did not improve from 0.00171
# Epoch 11/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0207 - mape: 761.2283 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0216 - val_mape: 2128.9204
#
# Epoch 00011: val_loss did not improve from 0.00171
# Epoch 12/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0208 - mape: 791.5477 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0205 - val_mape: 1268.0242
#
# Epoch 00012: val_loss improved from 0.00171 to 0.00170, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 13/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 792.3083 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 948.0961
#
# Epoch 00013: val_loss did not improve from 0.00170
# Epoch 14/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0207 - mape: 621.0154 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0201 - val_mape: 410.8754
#
# Epoch 00014: val_loss did not improve from 0.00170
# Epoch 15/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 797.4616 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0209 - val_mape: 1822.1515
#
# Epoch 00015: val_loss did not improve from 0.00170
# Epoch 16/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 832.1791 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0209 - val_mape: 579.2966
#
# Epoch 00016: val_loss improved from 0.00170 to 0.00170, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 17/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 788.9076 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0211 - val_mape: 1297.4491
#
# Epoch 00017: val_loss did not improve from 0.00170
# Epoch 18/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 856.6331 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 1018.3774
#
# Epoch 00018: val_loss did not improve from 0.00170
# Epoch 19/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 746.9623 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 745.4012
#
# Epoch 00019: val_loss did not improve from 0.00170
# Epoch 20/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 910.2811 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0203 - val_mape: 1302.7871
#
# Epoch 00020: val_loss improved from 0.00170 to 0.00170, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 21/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 906.4052 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 772.4534
#
# Epoch 00021: val_loss did not improve from 0.00170
# Epoch 22/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 913.2685 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0205 - val_mape: 671.1763
#
# Epoch 00022: val_loss did not improve from 0.00170
# Epoch 23/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 743.5558 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0211 - val_mape: 1169.5487
#
# Epoch 00023: val_loss did not improve from 0.00170
# Epoch 24/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 778.1904 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 1479.7245
#
# Epoch 00024: val_loss did not improve from 0.00170
# Epoch 25/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 757.4157 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0216 - val_mape: 2146.5872
#
# Epoch 00025: val_loss did not improve from 0.00170
# Epoch 26/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 761.7197 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 634.4736
#
# Epoch 00026: val_loss did not improve from 0.00170
# Epoch 27/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0204 - mape: 685.1066 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 962.0239
#
# Epoch 00027: val_loss improved from 0.00170 to 0.00170, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 28/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 657.2996 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0203 - val_mape: 1234.5603
#
# Epoch 00028: val_loss did not improve from 0.00170
# Epoch 29/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0204 - mape: 674.2004 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 1046.4993
#
# Epoch 00029: val_loss did not improve from 0.00170
# Epoch 30/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 727.6901 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 928.5888
#
# Epoch 00030: val_loss did not improve from 0.00170
# Epoch 31/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0207 - mape: 627.3519 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0208 - val_mape: 978.8409
#
# Epoch 00031: val_loss did not improve from 0.00170
# Epoch 32/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 887.0385 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 649.4566
#
# Epoch 00032: val_loss improved from 0.00170 to 0.00170, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 33/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 791.1891 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0215 - val_mape: 1157.2650
#
# Epoch 00033: val_loss did not improve from 0.00170
# Epoch 34/500
# 7929/7929 [==============================] - 16s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 640.0078 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 1122.4958
#
# Epoch 00034: val_loss improved from 0.00170 to 0.00170, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 35/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 676.5644 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0202 - val_mape: 1016.7210
#
# Epoch 00035: val_loss did not improve from 0.00170
# Epoch 36/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 683.3541 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0203 - val_mape: 1200.2028
#
# Epoch 00036: val_loss did not improve from 0.00170
# Epoch 37/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 743.6765 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 1282.7244
#
# Epoch 00037: val_loss did not improve from 0.00170
# Epoch 38/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 742.7468 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 839.1823
#
# Epoch 00038: val_loss did not improve from 0.00170
# Epoch 39/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0204 - mape: 940.3484 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 831.5825
#
# Epoch 00039: val_loss did not improve from 0.00170
# Epoch 40/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 707.5895 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0208 - val_mape: 1006.1907
#
# Epoch 00040: val_loss did not improve from 0.00170
# Epoch 41/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 722.1237 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0210 - val_mape: 1296.3459
#
# Epoch 00041: val_loss did not improve from 0.00170
# Epoch 42/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0204 - mape: 801.5407 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0210 - val_mape: 637.1655
#
# Epoch 00042: val_loss did not improve from 0.00170
# Epoch 43/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 856.8047 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0203 - val_mape: 1148.0660
#
# Epoch 00043: val_loss did not improve from 0.00170
# Epoch 44/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 774.2279 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 1313.6162
#
# Epoch 00044: val_loss did not improve from 0.00170
# Epoch 45/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 812.5289 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0210 - val_mape: 1597.9484
#
# Epoch 00045: val_loss did not improve from 0.00170
# Epoch 46/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 780.7747 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0205 - val_mape: 1057.4664
#
# Epoch 00046: val_loss did not improve from 0.00170
# Epoch 47/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 707.3908 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 1381.8127
#
# Epoch 00047: val_loss did not improve from 0.00170
# Epoch 48/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 685.9569 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0208 - val_mape: 1591.7830
#
# Epoch 00048: val_loss did not improve from 0.00170
# Epoch 49/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 741.6491 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 1226.4521
#
# Epoch 00049: val_loss did not improve from 0.00170
# Epoch 50/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0204 - mape: 806.4326 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0210 - val_mape: 1198.6722
#
# Epoch 00050: val_loss did not improve from 0.00170
# Epoch 51/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 719.5656 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0203 - val_mape: 446.7754
#
# Epoch 00051: val_loss did not improve from 0.00170
# Epoch 52/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0204 - mape: 735.7625 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 1402.7502
#
# Epoch 00052: val_loss did not improve from 0.00170
# Epoch 53/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 792.8180 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0205 - val_mape: 1323.7845
#
# Epoch 00053: val_loss did not improve from 0.00170
# Epoch 54/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 804.0767 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 1784.3619
#
# Epoch 00054: val_loss did not improve from 0.00170
# Epoch 55/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 778.1115 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 955.4158
#
# Epoch 00055: val_loss improved from 0.00170 to 0.00169, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 56/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0204 - mape: 698.7924 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 1580.6357
#
# Epoch 00056: val_loss did not improve from 0.00169
# Epoch 57/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 905.3684 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0203 - val_mape: 1042.3256
#
# Epoch 00057: val_loss did not improve from 0.00169
# Epoch 58/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 806.1478 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0203 - val_mape: 494.1425
#
# Epoch 00058: val_loss did not improve from 0.00169
# Epoch 59/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0207 - mape: 862.9409 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0208 - val_mape: 809.7846
#
# Epoch 00059: val_loss did not improve from 0.00169
# Epoch 60/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 861.0885 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0205 - val_mape: 1155.8406
#
# Epoch 00060: val_loss did not improve from 0.00169
# Epoch 61/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 799.9823 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 521.2054
#
# Epoch 00061: val_loss did not improve from 0.00169
# Epoch 62/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 861.4647 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0210 - val_mape: 2128.1426
#
# Epoch 00062: val_loss did not improve from 0.00169
# Epoch 63/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 746.0568 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0202 - val_mape: 1239.8229
#
# Epoch 00063: val_loss did not improve from 0.00169
# Epoch 64/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 743.0716 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0202 - val_mape: 897.3505
#
# Epoch 00064: val_loss did not improve from 0.00169
# Epoch 65/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 1044.7329 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0210 - val_mape: 1247.5717
#
# Epoch 00065: val_loss did not improve from 0.00169
# Epoch 66/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 768.8214 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 1881.6053
#
# Epoch 00066: val_loss improved from 0.00169 to 0.00169, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 67/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 845.7905 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0201 - val_mape: 860.7131
#
# Epoch 00067: val_loss did not improve from 0.00169
# Epoch 68/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 851.3011 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 1253.5067
#
# Epoch 00068: val_loss did not improve from 0.00169
# Epoch 69/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0204 - mape: 750.6751 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0217 - val_mape: 1447.2672
#
# Epoch 00069: val_loss did not improve from 0.00169
# Epoch 70/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 720.1000 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 1344.9058
#
# Epoch 00070: val_loss did not improve from 0.00169
# Epoch 71/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 949.8975 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 1077.4995
#
# Epoch 00071: val_loss did not improve from 0.00169
# Epoch 72/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 859.5852 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 1064.6572
#
# Epoch 00072: val_loss did not improve from 0.00169
# Epoch 73/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 999.1392 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0203 - val_mape: 1219.2825
#
# Epoch 00073: val_loss did not improve from 0.00169
# Epoch 74/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 889.6297 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 535.9207
#
# Epoch 00074: val_loss did not improve from 0.00169
# Epoch 75/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 768.9817 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0205 - val_mape: 1417.6437
#
# Epoch 00075: val_loss improved from 0.00169 to 0.00169, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 76/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 683.6034 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 602.3839
#
# Epoch 00076: val_loss did not improve from 0.00169
# Epoch 77/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 902.1124 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0208 - val_mape: 1977.5349
#
# Epoch 00077: val_loss did not improve from 0.00169
# Epoch 78/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0208 - mape: 727.3546 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0202 - val_mape: 929.5986
#
# Epoch 00078: val_loss did not improve from 0.00169
# Epoch 79/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 881.5983 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 723.0667
#
# Epoch 00079: val_loss did not improve from 0.00169
# Epoch 80/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 968.8168 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0214 - val_mape: 1976.0280
#
# Epoch 00080: val_loss did not improve from 0.00169
# Epoch 81/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 955.9690 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 1194.4594
#
# Epoch 00081: val_loss did not improve from 0.00169
# Epoch 82/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 878.1209 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 771.8112
#
# Epoch 00082: val_loss did not improve from 0.00169
# Epoch 83/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 693.4524 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0205 - val_mape: 745.0210
#
# Epoch 00083: val_loss did not improve from 0.00169
# Epoch 84/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 736.4693 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 1247.6865
#
# Epoch 00084: val_loss did not improve from 0.00169
# Epoch 85/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 693.5515 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0210 - val_mape: 984.3824
#
# Epoch 00085: val_loss did not improve from 0.00169
# Epoch 86/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 770.6352 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0208 - val_mape: 991.7925
#
# Epoch 00086: val_loss did not improve from 0.00169
# Epoch 87/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 739.3745 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 1445.3860
#
# Epoch 00087: val_loss did not improve from 0.00169
# Epoch 88/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 741.6511 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0212 - val_mape: 1460.5762
#
# Epoch 00088: val_loss did not improve from 0.00169
# Epoch 89/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 851.0320 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0211 - val_mape: 1283.4166
#
# Epoch 00089: val_loss did not improve from 0.00169
# Epoch 90/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 744.7490 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0208 - val_mape: 1156.9001
#
# Epoch 00090: val_loss did not improve from 0.00169
# Epoch 91/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 752.5405 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0202 - val_mape: 1531.4084
#
# Epoch 00091: val_loss did not improve from 0.00169
# Epoch 92/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 702.6655 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 1029.5188
#
# Epoch 00092: val_loss did not improve from 0.00169
# Epoch 93/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 670.5396 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 443.5034
#
# Epoch 00093: val_loss did not improve from 0.00169
# Epoch 94/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 957.0805 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 1618.7577
#
# Epoch 00094: val_loss did not improve from 0.00169
# Epoch 95/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 887.9631 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 691.0096
#
# Epoch 00095: val_loss did not improve from 0.00169
# Epoch 96/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 682.2491 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0203 - val_mape: 881.4385
#
# Epoch 00096: val_loss did not improve from 0.00169
# Epoch 97/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 735.9366 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0207 - val_mape: 1418.2609
#
# Epoch 00097: val_loss did not improve from 0.00169
# Epoch 98/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0207 - mape: 943.6585 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0209 - val_mape: 1179.5258
#
# Epoch 00098: val_loss did not improve from 0.00169
# Epoch 99/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 855.7429 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0205 - val_mape: 1434.5393
#
# Epoch 00099: val_loss did not improve from 0.00169
# Epoch 100/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0206 - mape: 814.1567 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0210 - val_mape: 1321.4269
#
# Epoch 00100: val_loss did not improve from 0.00169
# Epoch 101/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 839.3863 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 1056.9283
#
# Epoch 00101: val_loss did not improve from 0.00169
# Epoch 102/500
# 7929/7929 [==============================] - 18s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 690.8682 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0210 - val_mape: 1238.7678
#
# Epoch 00102: val_loss did not improve from 0.00169
# Epoch 103/500
# 7929/7929 [==============================] - 18s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 719.4296 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0206 - val_mape: 292.3925
#
# Epoch 00103: val_loss did not improve from 0.00169
# Epoch 104/500
# 7929/7929 [==============================] - 18s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0204 - mape: 632.6985 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0204 - val_mape: 900.7321
#
# Epoch 00104: val_loss did not improve from 0.00169
# Epoch 105/500
# 7929/7929 [==============================] - 17s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0205 - mape: 754.3531 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0205 - val_mape: 1410.5804
#
# Epoch 00105: val_loss did not improve from 0.00169
# Epoch 00105: early stopping
# The running time is: 29.46 minutes

# %%
#Making a prediction
y_pred = model.predict(X_test)

#Inverse transform
y_test = scalerY.inverse_transform(y_test)
y_pred = scalerY.inverse_transform(y_pred)

# %%
#Metrics Global
print('Metrics Global')
mae = mean_absolute_error(y_test, y_pred)
print('The mae is: %.4f' %mae)
mse = mean_squared_error(y_test, y_pred)
print('The mse is: %.4f' %mse)
rmse = np.sqrt(mse).mean()
print('The rmse is: %.4f' %rmse)
r2 = r2_score(y_test, y_pred)
print('The R2 is: %.4f' %r2)

print('____________________________________________')
#Metrics for the qc
print('Metrics for qc')
mae_qc = mean_absolute_error(y_test[:, 0], y_pred[:, 0])
print('The mae is: %.4f MPa' %mae_qc)
mse_qc = mean_squared_error(y_test[:, 0], y_pred[:, 0])
print('The mse is: %.4f MPa' %mse_qc)
rmse_qc = np.sqrt(mse).mean()
print('The rmse is: %.4f MPa' %rmse_qc)
r2_qc = r2_score(y_test[:, 0], y_pred[:, 0])
print('The R2 is: %.4f MPa' %r2_qc)

print('____________________________________________')

#Metrics for the fs
print('Metrics for fs')
mae_fs = mean_absolute_error(y_test[:, 1], y_pred[:, 1])
print('The mae is: %.4f kPa' %mae_fs)
mse_fs = mean_squared_error(y_test[:, 1], y_pred[:, 1])
print('The mse is: %.4f kPa' %mse_fs)
rmse_fs = np.sqrt(mse).mean()
print('The rmse is: %.4f kPa' %rmse_fs)
r2_fs= r2_score(y_test[:, 1], y_pred[:, 1])
print('The R2 is: %.4f kPa' %r2_fs)
# Out:
# Metrics Global
# The mae is: 15.9584
# The mse is: 1525.4309
# The rmse is: 39.0568
# The R2 is: 0.5938
# ____________________________________________
# Metrics for qc
# The mae is: 1.7457 MPa
# The mse is: 14.7304 MPa
# The rmse is: 39.0568 MPa
# The R2 is: 0.7841 MPa
# ____________________________________________
# Metrics for fs
# The mae is: 30.1711 kPa
# The mse is: 3036.1315 kPa
# The rmse is: 39.0568 kPa
# The R2 is: 0.4036 kPa

# %%
#History
from google.colab import files
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
ax = plt.gca()
#ax.set_ylim([0, 0.05])
plt.savefig('Fig_DNN_CPPTNet_01.png', dpi = 600)
#files.download("Fig_DNN_CPPTNet_01.png")
plt.show()
