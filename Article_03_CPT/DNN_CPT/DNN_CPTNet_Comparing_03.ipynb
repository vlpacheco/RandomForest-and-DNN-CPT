# %%
"""
Global Feature Selection 
    - X = 'Depth (m)','iso_classes_encoded', 'Oberhollenzer_classes', 
    'σ,v (kPa)', 'σ',v (kPa)'.
    
    - Y = 'qc (MPa)','fs (kPa)'.
"""
#General Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, CSVLogger
from sklearn.model_selection import train_test_split
import time

'''
PreProcessing
''' 
#Loading Database
df_cpt=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Target_Encoded_Database.csv')

#Transforming to DataFrame
df_cpt = pd.DataFrame(df_cpt)
df_cpt = df_cpt.drop(columns='Unnamed: 0')

#Dropping zeros from qc
df_cpt = df_cpt[~(df_cpt[['qc (MPa)']] == 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['qc (MPa)']] < 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['SBT (-)']] == 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['SBTn (-)']] == 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['Mod. SBTn (-)']] == 0).any(axis = 1)]

#Transforming to NumpyArray
df_cpt = df_cpt.to_numpy()

'''
Inputs
'''
X = df_cpt[:, [17, 18, 19, 27]]

#1--> D'Depth (m)' --> index: 1
#2 --> 'σ,v (kPa)' --> index: 9
#3 --> "σ',v (kPa)" --> index: 11
#4 --> 'SBT (-)' --> index: 17
#5 --> 'SBTn (-)' --> index: 18
#6 --> 'Mod. SBTn (-)' --> index: 19 
#7 --> 'Ic (-)' --> index: 21
#8 --> 'Ic SBT (-)' --> index:22 
#9 --> 'Ib (-)' --> index: 23
#10 --> 'Oberhollenzer_classes' --> index: 24
#11 --> 'iso_classes_encoded' --> index: 27

#X=X.to(device) #To GPU

'''
Outputs
'''
y = df_cpt[:, [2, 3]] 

#1 --> 'qc (MPa)' --> index: 2
#2 --> 'fs (kPa)' --> index: 3

#y=y.to(device) #To GPU

#Scaling the and preparing the data
scalerX = MinMaxScaler()
scalerY = MinMaxScaler()

#Scaling the Data
scaledX=scalerX.fit_transform(X)
scaledY=scalerY.fit_transform(y)

#Train & Test split
X_train, X_test, y_train, y_test = train_test_split(scaledX, scaledY, 
                                                   test_size = 0.20)

# %%
'''
Neural Network Structure
'''
#Callbacks
es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, 
                   patience = 30)
csv_logger = CSVLogger('DNN_CPTNet_Colonel_03.csv', 
                       separator = ',', append = False)
model_checkpoint = ModelCheckpoint('DNN_CPTNet_Colonel_03.hdf5', 
                                   monitor = 'val_loss', verbose = 1, save_best_only = True)

#Optimizer
l_r = 0.001
momentum = 0.9
opt_1 = keras.optimizers.Nadam(learning_rate = l_r)
opt_2 = keras.optimizers.SGD(learning_rate = l_r, momentum = momentum)
opt_3 = tf.keras.optimizers.RMSprop(learning_rate = 0.001, rho=0.9, momentum = 0.0, epsilon=1e-07)
opt_4 = keras.optimizers.Adam(learning_rate = l_r)

#Weight Initializer
init_mode_1 = 'he_normal'
init_mode_2 = tf.keras.initializers.LecunNormal()

#Activation functions
trelu = tf.keras.layers.ThresholdedReLU(theta = 1.0)
prelu = tf.keras.layers.PReLU()
leaky_relu = tf.keras.layers.LeakyReLU(alpha = 0.3)

#Model
model = Sequential()

model.add(Dense(21, input_dim = 4,
                activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(2, activation = 'linear', 
                kernel_initializer = init_mode_1))

model.compile(optimizer = opt_1, loss = 'mse', 
              metrics=['mse', 'mae', 'mape'])

#Initial time
start_time = time.time()

#Fitting Network
history =  model.fit(X_train, y_train, epochs = 500, batch_size = 64,
                     validation_split = 0.25, callbacks = [model_checkpoint, csv_logger, es])

#Final time
end_time = (time.time() - start_time)
print('The running time is: %.2f minutes' %(end_time/60))
# Out:
# Epoch 1/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0266 - mape: 1529.4779 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0200 - val_mape: 566.0936
#
# Epoch 00001: val_loss improved from inf to 0.00164, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 2/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0208 - mape: 1038.9663 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0214 - val_mape: 1067.8853
#
# Epoch 00002: val_loss improved from 0.00164 to 0.00163, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 3/500
# 7929/7929 [==============================] - 10s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0202 - mape: 935.3471 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0199 - val_mape: 605.0688
#
# Epoch 00003: val_loss improved from 0.00163 to 0.00153, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 4/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0200 - mape: 1172.3877 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0192 - val_mape: 1322.9861
#
# Epoch 00004: val_loss did not improve from 0.00153
# Epoch 5/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0198 - mape: 1285.9289 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0201 - val_mape: 1824.6694
#
# Epoch 00005: val_loss improved from 0.00153 to 0.00150, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 6/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0198 - mape: 1093.8269 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0190 - val_mape: 1197.7368
#
# Epoch 00006: val_loss did not improve from 0.00150
# Epoch 7/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0197 - mape: 1303.2336 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0195 - val_mape: 1286.7926
#
# Epoch 00007: val_loss improved from 0.00150 to 0.00150, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 8/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0196 - mape: 1040.8612 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0196 - val_mape: 2090.7256
#
# Epoch 00008: val_loss did not improve from 0.00150
# Epoch 9/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0197 - mape: 1514.1215 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0200 - val_mape: 947.7702
#
# Epoch 00009: val_loss did not improve from 0.00150
# Epoch 10/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0196 - mape: 1330.3070 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0194 - val_mape: 833.4206
#
# Epoch 00010: val_loss did not improve from 0.00150
# Epoch 11/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0195 - mape: 1547.3431 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0209 - val_mape: 719.0682
#
# Epoch 00011: val_loss did not improve from 0.00150
# Epoch 12/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0195 - mape: 1249.9614 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0206 - val_mape: 1034.7244
#
# Epoch 00012: val_loss did not improve from 0.00150
# Epoch 13/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0196 - mape: 1280.3672 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0193 - val_mape: 769.2733
#
# Epoch 00013: val_loss improved from 0.00150 to 0.00148, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 14/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0194 - mape: 1259.7089 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0193 - val_mape: 901.0621
#
# Epoch 00014: val_loss improved from 0.00148 to 0.00148, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 15/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0195 - mape: 1692.7929 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0192 - val_mape: 1639.6050
#
# Epoch 00015: val_loss did not improve from 0.00148
# Epoch 16/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0194 - mape: 1386.3475 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0193 - val_mape: 699.8496
#
# Epoch 00016: val_loss did not improve from 0.00148
# Epoch 17/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0194 - mape: 1506.9943 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0189 - val_mape: 1131.5320
#
# Epoch 00017: val_loss did not improve from 0.00148
# Epoch 18/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0194 - mape: 1277.8093 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0196 - val_mape: 1719.6984
#
# Epoch 00018: val_loss did not improve from 0.00148
# Epoch 19/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0193 - mape: 1276.6253 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0190 - val_mape: 675.4159
#
# Epoch 00019: val_loss did not improve from 0.00148
# Epoch 20/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0193 - mape: 1087.1056 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0206 - val_mape: 1792.5428
#
# Epoch 00020: val_loss did not improve from 0.00148
# Epoch 21/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0193 - mape: 1318.7339 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0194 - val_mape: 1392.7419
#
# Epoch 00021: val_loss did not improve from 0.00148
# Epoch 22/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0193 - mape: 972.4453 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0190 - val_mape: 1766.9944
#
# Epoch 00022: val_loss did not improve from 0.00148
# Epoch 23/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0193 - mape: 1611.0542 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0193 - val_mape: 909.7250
#
# Epoch 00023: val_loss did not improve from 0.00148
# Epoch 24/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0193 - mape: 1787.9093 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0193 - val_mape: 1040.6782
#
# Epoch 00024: val_loss did not improve from 0.00148
# Epoch 25/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1456.3924 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0191 - val_mape: 1572.5198
#
# Epoch 00025: val_loss improved from 0.00148 to 0.00147, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 26/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1454.2761 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0195 - val_mape: 1293.3835
#
# Epoch 00026: val_loss did not improve from 0.00147
# Epoch 27/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1404.8041 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0192 - val_mape: 1917.4852
#
# Epoch 00027: val_loss did not improve from 0.00147
# Epoch 28/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1340.4797 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0194 - val_mape: 1539.1888
#
# Epoch 00028: val_loss did not improve from 0.00147
# Epoch 29/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0193 - mape: 1751.8834 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0188 - val_mape: 1744.7184
#
# Epoch 00029: val_loss did not improve from 0.00147
# Epoch 30/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1542.4572 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0207 - val_mape: 2612.2610
#
# Epoch 00030: val_loss did not improve from 0.00147
# Epoch 31/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0193 - mape: 1403.5128 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0192 - val_mape: 1582.8934
#
# Epoch 00031: val_loss did not improve from 0.00147
# Epoch 32/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1429.0247 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0193 - val_mape: 1722.1115
#
# Epoch 00032: val_loss improved from 0.00147 to 0.00147, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 33/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1518.3840 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0190 - val_mape: 1389.8884
#
# Epoch 00033: val_loss did not improve from 0.00147
# Epoch 34/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0193 - mape: 1925.4847 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0188 - val_mape: 1579.4723
#
# Epoch 00034: val_loss did not improve from 0.00147
# Epoch 35/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0192 - mape: 1904.9609 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0196 - val_mape: 1884.8684
#
# Epoch 00035: val_loss did not improve from 0.00147
# Epoch 36/500
# 7929/7929 [==============================] - 15s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1385.5892 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0190 - val_mape: 2218.0063
#
# Epoch 00036: val_loss improved from 0.00147 to 0.00145, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 37/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1673.1843 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0195 - val_mape: 2040.3606
#
# Epoch 00037: val_loss did not improve from 0.00145
# Epoch 38/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0192 - mape: 1767.5159 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0199 - val_mape: 2812.6323
#
# Epoch 00038: val_loss did not improve from 0.00145
# Epoch 39/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1626.0266 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0189 - val_mape: 1372.8864
#
# Epoch 00039: val_loss did not improve from 0.00145
# Epoch 40/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1596.7557 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0189 - val_mape: 1494.9304
#
# Epoch 00040: val_loss improved from 0.00145 to 0.00145, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 41/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1734.2448 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0190 - val_mape: 1769.4733
#
# Epoch 00041: val_loss improved from 0.00145 to 0.00144, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 42/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1598.9037 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0191 - val_mape: 1254.3706
#
# Epoch 00042: val_loss did not improve from 0.00144
# Epoch 43/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1483.0887 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0194 - val_mape: 1170.8701
#
# Epoch 00043: val_loss did not improve from 0.00144
# Epoch 44/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0192 - mape: 1608.8938 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0190 - val_mape: 1215.0911
#
# Epoch 00044: val_loss did not improve from 0.00144
# Epoch 45/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1576.9272 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0191 - val_mape: 1528.4191
#
# Epoch 00045: val_loss did not improve from 0.00144
# Epoch 46/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0192 - mape: 1752.8654 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0196 - val_mape: 1053.7118
#
# Epoch 00046: val_loss did not improve from 0.00144
# Epoch 47/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1388.9902 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0192 - val_mape: 692.3620
#
# Epoch 00047: val_loss did not improve from 0.00144
# Epoch 48/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0192 - mape: 1207.7755 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0202 - val_mape: 836.9999
#
# Epoch 00048: val_loss did not improve from 0.00144
# Epoch 49/500
# 7929/7929 [==============================] - 11s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1199.0849 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0191 - val_mape: 1167.5134
#
# Epoch 00049: val_loss did not improve from 0.00144
# Epoch 50/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1309.4085 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0194 - val_mape: 2472.6047
#
# Epoch 00050: val_loss did not improve from 0.00144
# Epoch 51/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0190 - mape: 1719.5347 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0195 - val_mape: 1694.3352
#
# Epoch 00051: val_loss did not improve from 0.00144
# Epoch 52/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1485.2684 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0193 - val_mape: 1731.0363
#
# Epoch 00052: val_loss did not improve from 0.00144
# Epoch 53/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0190 - mape: 1220.0321 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0185 - val_mape: 1550.7388
#
# Epoch 00053: val_loss did not improve from 0.00144
# Epoch 54/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1481.3104 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0192 - val_mape: 1179.3768
#
# Epoch 00054: val_loss did not improve from 0.00144
# Epoch 55/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0193 - mape: 1807.8444 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0197 - val_mape: 1606.0643
#
# Epoch 00055: val_loss did not improve from 0.00144
# Epoch 56/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0193 - mape: 1958.0449 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0195 - val_mape: 1489.4618
#
# Epoch 00056: val_loss did not improve from 0.00144
# Epoch 57/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0193 - mape: 1716.2890 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0192 - val_mape: 1238.5658
#
# Epoch 00057: val_loss did not improve from 0.00144
# Epoch 58/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1608.2348 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0194 - val_mape: 1118.5712
#
# Epoch 00058: val_loss did not improve from 0.00144
# Epoch 59/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1330.7976 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0189 - val_mape: 1164.9204
#
# Epoch 00059: val_loss improved from 0.00144 to 0.00144, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 60/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1816.1875 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0194 - val_mape: 2734.2571
#
# Epoch 00060: val_loss did not improve from 0.00144
# Epoch 61/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1444.7217 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0194 - val_mape: 1078.7933
#
# Epoch 00061: val_loss did not improve from 0.00144
# Epoch 62/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0192 - mape: 1652.1324 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0197 - val_mape: 1919.9618
#
# Epoch 00062: val_loss did not improve from 0.00144
# Epoch 63/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1377.5352 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0187 - val_mape: 1517.7097
#
# Epoch 00063: val_loss did not improve from 0.00144
# Epoch 64/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1581.2800 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0189 - val_mape: 1238.6904
#
# Epoch 00064: val_loss improved from 0.00144 to 0.00143, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 65/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1426.0521 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0189 - val_mape: 1793.5958
#
# Epoch 00065: val_loss did not improve from 0.00143
# Epoch 66/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0190 - mape: 1376.8594 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0196 - val_mape: 1252.5114
#
# Epoch 00066: val_loss did not improve from 0.00143
# Epoch 67/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1436.9203 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0193 - val_mape: 1479.8556
#
# Epoch 00067: val_loss did not improve from 0.00143
# Epoch 68/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1532.5622 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0204 - val_mape: 2024.4011
#
# Epoch 00068: val_loss did not improve from 0.00143
# Epoch 69/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1203.7973 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0190 - val_mape: 2000.2216
#
# Epoch 00069: val_loss did not improve from 0.00143
# Epoch 70/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1332.6064 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0188 - val_mape: 1620.5812
#
# Epoch 00070: val_loss did not improve from 0.00143
# Epoch 71/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1270.0273 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0189 - val_mape: 1055.9609
#
# Epoch 00071: val_loss did not improve from 0.00143
# Epoch 72/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1384.4844 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0188 - val_mape: 1220.1274
#
# Epoch 00072: val_loss did not improve from 0.00143
# Epoch 73/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1352.6464 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0188 - val_mape: 1362.3857
#
# Epoch 00073: val_loss did not improve from 0.00143
# Epoch 74/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1390.9667 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0190 - val_mape: 1571.8850
#
# Epoch 00074: val_loss did not improve from 0.00143
# Epoch 75/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1543.5793 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0190 - val_mape: 1383.5250
#
# Epoch 00075: val_loss did not improve from 0.00143
# Epoch 76/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0190 - mape: 1511.0599 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0196 - val_mape: 1064.2781
#
# Epoch 00076: val_loss did not improve from 0.00143
# Epoch 77/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1621.4652 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0192 - val_mape: 1224.6775
#
# Epoch 00077: val_loss did not improve from 0.00143
# Epoch 78/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1156.7106 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0193 - val_mape: 1617.6195
#
# Epoch 00078: val_loss did not improve from 0.00143
# Epoch 79/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1333.1912 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0196 - val_mape: 1910.2172
#
# Epoch 00079: val_loss did not improve from 0.00143
# Epoch 80/500
# 7929/7929 [==============================] - 12s 1ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0190 - mape: 1293.2862 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0207 - val_mape: 1997.2744
#
# Epoch 00080: val_loss did not improve from 0.00143
# Epoch 81/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1182.6011 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0197 - val_mape: 1833.8098
#
# Epoch 00081: val_loss did not improve from 0.00143
# Epoch 82/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0193 - mape: 1183.0256 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0201 - val_mape: 2095.3762
#
# Epoch 00082: val_loss did not improve from 0.00143
# Epoch 83/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0193 - mape: 1459.8065 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0192 - val_mape: 1436.1780
#
# Epoch 00083: val_loss did not improve from 0.00143
# Epoch 84/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1366.3371 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0194 - val_mape: 2352.6472
#
# Epoch 00084: val_loss did not improve from 0.00143
# Epoch 85/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1471.8326 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0207 - val_mape: 2384.9988
#
# Epoch 00085: val_loss did not improve from 0.00143
# Epoch 86/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1519.6982 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0192 - val_mape: 2186.5525
#
# Epoch 00086: val_loss did not improve from 0.00143
# Epoch 87/500
# 7929/7929 [==============================] - 13s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1541.2905 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0192 - val_mape: 2230.4753
#
# Epoch 00087: val_loss did not improve from 0.00143
# Epoch 88/500
# 7929/7929 [==============================] - 14s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1814.6701 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0193 - val_mape: 2298.7310
#
# Epoch 00088: val_loss did not improve from 0.00143
# Epoch 89/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 2469.4436 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0191 - val_mape: 1568.0929
#
# Epoch 00089: val_loss did not improve from 0.00143
# Epoch 90/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0192 - mape: 2062.3991 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0194 - val_mape: 1674.2477
#
# Epoch 00090: val_loss did not improve from 0.00143
# Epoch 91/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1600.3522 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0196 - val_mape: 2242.4795
#
# Epoch 00091: val_loss did not improve from 0.00143
# Epoch 92/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0191 - mape: 1520.6617 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0192 - val_mape: 1346.0665
#
# Epoch 00092: val_loss did not improve from 0.00143
# Epoch 93/500
# 7929/7929 [==============================] - 13s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0192 - mape: 1111.9056 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0189 - val_mape: 1569.3901
#
# Epoch 00093: val_loss did not improve from 0.00143
# Epoch 94/500
# 7929/7929 [==============================] - 12s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0190 - mape: 1222.9138 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0199 - val_mape: 1400.0410
#
# Epoch 00094: val_loss did not improve from 0.00143
# Epoch 00094: early stopping
# The running time is: 18.02 minutes

# %%
#Making a prediction
y_pred = model.predict(X_test)

#Inverse transform
y_test = scalerY.inverse_transform(y_test)
y_pred = scalerY.inverse_transform(y_pred)

# %%
#Metrics Global
print('Metrics Global')
mae = mean_absolute_error(y_test, y_pred)
print('The mae is: %.4f' %mae)
mse = mean_squared_error(y_test, y_pred)
print('The mse is: %.4f' %mse)
rmse = np.sqrt(mse).mean()
print('The rmse is: %.4f' %rmse)
r2 = r2_score(y_test, y_pred)
print('The R2 is: %.4f' %r2)

print('____________________________________________')
#Metrics for the qc
print('Metrics for qc')
mae_qc = mean_absolute_error(y_test[:, 0], y_pred[:, 0])
print('The mae is: %.4f MPa' %mae_qc)
mse_qc = mean_squared_error(y_test[:, 0], y_pred[:, 0])
print('The mse is: %.4f MPa' %mse_qc)
rmse_qc = np.sqrt(mse).mean()
print('The rmse is: %.4f MPa' %rmse_qc)
r2_qc = r2_score(y_test[:, 0], y_pred[:, 0])
print('The R2 is: %.4f MPa' %r2_qc)

print('____________________________________________')

#Metrics for the fs
print('Metrics for fs')
mae_fs = mean_absolute_error(y_test[:, 1], y_pred[:, 1])
print('The mae is: %.4f kPa' %mae_fs)
mse_fs = mean_squared_error(y_test[:, 1], y_pred[:, 1])
print('The mse is: %.4f kPa' %mse_fs)
rmse_fs = np.sqrt(mse).mean()
print('The rmse is: %.4f kPa' %rmse_fs)
r2_fs= r2_score(y_test[:, 1], y_pred[:, 1])
print('The R2 is: %.4f kPa' %r2_fs)
# Out:
# Metrics Global
# The mae is: 15.6180
# The mse is: 1288.9372
# The rmse is: 35.9018
# The R2 is: 0.6578
# ____________________________________________
# Metrics for qc
# The mae is: 1.6543 MPa
# The mse is: 12.3141 MPa
# The rmse is: 35.9018 MPa
# The R2 is: 0.8186 MPa
# ____________________________________________
# Metrics for fs
# The mae is: 29.5817 kPa
# The mse is: 2565.5604 kPa
# The rmse is: 35.9018 kPa
# The R2 is: 0.4970 kPa

# %%
#History
from google.colab import files
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
ax = plt.gca()
#ax.set_ylim([0, 0.05])
plt.savefig('Fig_DNN_CPPTNet_01.png', dpi = 600)
#files.download("Fig_DNN_CPPTNet_01.png")
plt.show()
