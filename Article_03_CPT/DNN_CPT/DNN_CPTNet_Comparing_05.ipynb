# %%
"""
Global Feature Selection 
    - X = 'Depth (m)','iso_classes_encoded', 'Oberhollenzer_classes', 
    'σ,v (kPa)', 'σ',v (kPa)'.
    
    - Y = 'qc (MPa)','fs (kPa)'.
"""
#General Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, CSVLogger
from sklearn.model_selection import train_test_split
import time

'''
PreProcessing
''' 
#Loading Database
df_cpt=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Target_Encoded_Database.csv')

#Transforming to DataFrame
df_cpt = pd.DataFrame(df_cpt)
df_cpt = df_cpt.drop(columns='Unnamed: 0')

#Dropping zeros from qc
df_cpt = df_cpt[~(df_cpt[['qc (MPa)']] == 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['qc (MPa)']] < 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['SBT (-)']] == 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['SBTn (-)']] == 0).any(axis = 1)]
df_cpt = df_cpt[~(df_cpt[['Mod. SBTn (-)']] == 0).any(axis = 1)]

#Transforming to NumpyArray
df_cpt = df_cpt.to_numpy()

'''
Inputs
'''
X = df_cpt[:, [17, 18]]

#1--> D'Depth (m)' --> index: 1
#2 --> 'σ,v (kPa)' --> index: 9
#3 --> "σ',v (kPa)" --> index: 11
#4 --> 'SBT (-)' --> index: 17
#5 --> 'SBTn (-)' --> index: 18
#6 --> 'Mod. SBTn (-)' --> index: 19 
#7 --> 'Ic (-)' --> index: 21
#8 --> 'Ic SBT (-)' --> index:22 
#9 --> 'Ib (-)' --> index: 23
#10 --> 'Oberhollenzer_classes' --> index: 24
#11 --> 'iso_classes_encoded' --> index: 27

#X=X.to(device) #To GPU

'''
Outputs
'''
y = df_cpt[:, [2, 3]] 

#1 --> 'qc (MPa)' --> index: 2
#2 --> 'fs (kPa)' --> index: 3

#y=y.to(device) #To GPU

#Scaling the and preparing the data
scalerX = MinMaxScaler()
scalerY = MinMaxScaler()

#Scaling the Data
scaledX=scalerX.fit_transform(X)
scaledY=scalerY.fit_transform(y)

#Train & Test split
X_train, X_test, y_train, y_test = train_test_split(scaledX, scaledY, 
                                                   test_size = 0.20)

# %%
'''
Neural Network Structure
'''
#Callbacks
es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, 
                   patience = 30)
csv_logger = CSVLogger('DNN_CPTNet_Colonel_03.csv', 
                       separator = ',', append = False)
model_checkpoint = ModelCheckpoint('DNN_CPTNet_Colonel_03.hdf5', 
                                   monitor = 'val_loss', verbose = 1, save_best_only = True)

#Optimizer
l_r = 0.001
momentum = 0.9
opt_1 = keras.optimizers.Nadam(learning_rate = l_r)
opt_2 = keras.optimizers.SGD(learning_rate = l_r, momentum = momentum)
opt_3 = tf.keras.optimizers.RMSprop(learning_rate = 0.001, rho=0.9, momentum = 0.0, epsilon=1e-07)
opt_4 = keras.optimizers.Adam(learning_rate = l_r)

#Weight Initializer
init_mode_1 = 'he_normal'
init_mode_2 = tf.keras.initializers.LecunNormal()

#Activation functions
trelu = tf.keras.layers.ThresholdedReLU(theta = 1.0)
prelu = tf.keras.layers.PReLU()
leaky_relu = tf.keras.layers.LeakyReLU(alpha = 0.3)

#Model
model = Sequential()

model.add(Dense(21, input_dim = 2,
                activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(21, activation = 'relu',
                kernel_initializer = init_mode_1))

model.add(Dense(2, activation = 'linear', 
                kernel_initializer = init_mode_1))

model.compile(optimizer = opt_1, loss = 'mse', 
              metrics=['mse', 'mae', 'mape'])

#Initial time
start_time = time.time()

#Fitting Network
history =  model.fit(X_train, y_train, epochs = 500, batch_size = 64,
                     validation_split = 0.25, callbacks = [model_checkpoint, csv_logger, es])

#Final time
end_time = (time.time() - start_time)
print('The running time is: %.2f minutes' %(end_time/60))
# Out:
# Epoch 1/500
# 7929/7929 [==============================] - 26s 3ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0258 - mape: 1227.3542 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0234 - val_mape: 275.5078
#
# Epoch 00001: val_loss improved from inf to 0.00201, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 2/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0243 - mape: 885.6235 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0247 - val_mape: 1295.2209
#
# Epoch 00002: val_loss improved from 0.00201 to 0.00199, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 3/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0242 - mape: 1132.2264 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0258 - val_mape: 1095.0725
#
# Epoch 00003: val_loss did not improve from 0.00199
# Epoch 4/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0241 - mape: 1050.0569 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0233 - val_mape: 747.4398
#
# Epoch 00004: val_loss improved from 0.00199 to 0.00197, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 5/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0240 - mape: 977.6430 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0249 - val_mape: 1597.2975
#
# Epoch 00005: val_loss did not improve from 0.00197
# Epoch 6/500
# 7929/7929 [==============================] - 20s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0240 - mape: 894.6938 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0232 - val_mape: 927.6133
#
# Epoch 00006: val_loss did not improve from 0.00197
# Epoch 7/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0240 - mape: 902.7046 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0244 - val_mape: 608.2167
#
# Epoch 00007: val_loss improved from 0.00197 to 0.00197, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 8/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0240 - mape: 866.8261 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0229 - val_mape: 385.5598
#
# Epoch 00008: val_loss did not improve from 0.00197
# Epoch 9/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 869.0096 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0242 - val_mape: 864.9579
#
# Epoch 00009: val_loss improved from 0.00197 to 0.00197, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 10/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 815.0772 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0235 - val_mape: 870.9963
#
# Epoch 00010: val_loss did not improve from 0.00197
# Epoch 11/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0240 - mape: 842.1819 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0236 - val_mape: 925.3227
#
# Epoch 00011: val_loss did not improve from 0.00197
# Epoch 12/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0240 - mape: 813.8660 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0239 - val_mape: 1093.5782
#
# Epoch 00012: val_loss improved from 0.00197 to 0.00196, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 13/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0240 - mape: 837.8873 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0242 - val_mape: 1005.9713
#
# Epoch 00013: val_loss did not improve from 0.00196
# Epoch 14/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0240 - mape: 871.8580 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0238 - val_mape: 558.7576
#
# Epoch 00014: val_loss did not improve from 0.00196
# Epoch 15/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0240 - mape: 896.5022 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0242 - val_mape: 927.6157
#
# Epoch 00015: val_loss improved from 0.00196 to 0.00196, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 16/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0240 - mape: 997.7762 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0241 - val_mape: 717.6302
#
# Epoch 00016: val_loss did not improve from 0.00196
# Epoch 17/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 823.3774 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0246 - val_mape: 1190.0023
#
# Epoch 00017: val_loss did not improve from 0.00196
# Epoch 18/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 937.1078 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0233 - val_mape: 452.3296
#
# Epoch 00018: val_loss did not improve from 0.00196
# Epoch 19/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 900.8687 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0238 - val_mape: 991.8364
#
# Epoch 00019: val_loss did not improve from 0.00196
# Epoch 20/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 1053.1475 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0241 - val_mape: 538.1162
#
# Epoch 00020: val_loss did not improve from 0.00196
# Epoch 21/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 973.7762 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0236 - val_mape: 118.5513
#
# Epoch 00021: val_loss did not improve from 0.00196
# Epoch 22/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 925.8582 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0241 - val_mape: 355.2966
#
# Epoch 00022: val_loss did not improve from 0.00196
# Epoch 23/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 995.1679 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0234 - val_mape: 369.4553
#
# Epoch 00023: val_loss did not improve from 0.00196
# Epoch 24/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 903.7438 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0235 - val_mape: 389.4719
#
# Epoch 00024: val_loss improved from 0.00196 to 0.00196, saving model to DNN_CPTNet_Colonel_03.hdf5
# Epoch 25/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 835.2230 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0237 - val_mape: 1032.3702
#
# Epoch 00025: val_loss did not improve from 0.00196
# Epoch 26/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 915.7655 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0242 - val_mape: 513.7176
#
# Epoch 00026: val_loss did not improve from 0.00196
# Epoch 27/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 936.1486 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0237 - val_mape: 171.8481
#
# Epoch 00027: val_loss did not improve from 0.00196
# Epoch 28/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 909.9265 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0235 - val_mape: 454.1726
#
# Epoch 00028: val_loss did not improve from 0.00196
# Epoch 29/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 862.8953 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0237 - val_mape: 782.4071
#
# Epoch 00029: val_loss did not improve from 0.00196
# Epoch 30/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 867.0996 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0232 - val_mape: 993.6649
#
# Epoch 00030: val_loss did not improve from 0.00196
# Epoch 31/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 915.7200 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0247 - val_mape: 1513.2941
#
# Epoch 00031: val_loss did not improve from 0.00196
# Epoch 32/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 903.9778 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0245 - val_mape: 860.9837
#
# Epoch 00032: val_loss did not improve from 0.00196
# Epoch 33/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 910.1500 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0245 - val_mape: 1162.3684
#
# Epoch 00033: val_loss did not improve from 0.00196
# Epoch 34/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 898.4554 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0241 - val_mape: 1249.7732
#
# Epoch 00034: val_loss did not improve from 0.00196
# Epoch 35/500
# 7929/7929 [==============================] - 25s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 900.1005 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0233 - val_mape: 255.7247
#
# Epoch 00035: val_loss did not improve from 0.00196
# Epoch 36/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 867.4002 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0246 - val_mape: 850.7980
#
# Epoch 00036: val_loss did not improve from 0.00196
# Epoch 37/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 920.6237 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0234 - val_mape: 365.0034
#
# Epoch 00037: val_loss did not improve from 0.00196
# Epoch 38/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 860.2316 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0236 - val_mape: 903.6124
#
# Epoch 00038: val_loss did not improve from 0.00196
# Epoch 39/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 918.3152 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0241 - val_mape: 978.1412
#
# Epoch 00039: val_loss did not improve from 0.00196
# Epoch 40/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 917.1993 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0238 - val_mape: 1044.0250
#
# Epoch 00040: val_loss did not improve from 0.00196
# Epoch 41/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 894.1218 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0239 - val_mape: 305.3240
#
# Epoch 00041: val_loss did not improve from 0.00196
# Epoch 42/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 995.3259 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0243 - val_mape: 215.9681
#
# Epoch 00042: val_loss did not improve from 0.00196
# Epoch 43/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 995.3287 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0236 - val_mape: 1073.7294
#
# Epoch 00043: val_loss did not improve from 0.00196
# Epoch 44/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 936.7019 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0241 - val_mape: 1621.8751
#
# Epoch 00044: val_loss did not improve from 0.00196
# Epoch 45/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 918.1572 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0238 - val_mape: 716.2424
#
# Epoch 00045: val_loss did not improve from 0.00196
# Epoch 46/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 904.1973 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0242 - val_mape: 970.5600
#
# Epoch 00046: val_loss did not improve from 0.00196
# Epoch 47/500
# 7929/7929 [==============================] - 22s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 944.4459 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0238 - val_mape: 667.5066
#
# Epoch 00047: val_loss did not improve from 0.00196
# Epoch 48/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 954.8904 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0243 - val_mape: 1048.5964
#
# Epoch 00048: val_loss did not improve from 0.00196
# Epoch 49/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 973.6075 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0233 - val_mape: 106.6305
#
# Epoch 00049: val_loss did not improve from 0.00196
# Epoch 50/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 991.6546 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0234 - val_mape: 529.9648
#
# Epoch 00050: val_loss did not improve from 0.00196
# Epoch 51/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 906.7374 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0240 - val_mape: 842.4724
#
# Epoch 00051: val_loss did not improve from 0.00196
# Epoch 52/500
# 7929/7929 [==============================] - 21s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 893.1443 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0244 - val_mape: 1026.6450
#
# Epoch 00052: val_loss did not improve from 0.00196
# Epoch 53/500
# 7929/7929 [==============================] - 24s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 886.8233 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0234 - val_mape: 600.5306
#
# Epoch 00053: val_loss did not improve from 0.00196
# Epoch 54/500
# 7929/7929 [==============================] - 23s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0239 - mape: 877.4860 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0240 - val_mape: 378.8154
#
# Epoch 00054: val_loss did not improve from 0.00196
# Epoch 00054: early stopping
# The running time is: 20.23 minutes

# %%
#Making a prediction
y_pred = model.predict(X_test)

#Inverse transform
y_test = scalerY.inverse_transform(y_test)
y_pred = scalerY.inverse_transform(y_pred)

# %%
#Metrics Global
print('Metrics Global')
mae = mean_absolute_error(y_test, y_pred)
print('The mae is: %.4f' %mae)
mse = mean_squared_error(y_test, y_pred)
print('The mse is: %.4f' %mse)
rmse = np.sqrt(mse).mean()
print('The rmse is: %.4f' %rmse)
r2 = r2_score(y_test, y_pred)
print('The R2 is: %.4f' %r2)

print('____________________________________________')
#Metrics for the qc
print('Metrics for qc')
mae_qc = mean_absolute_error(y_test[:, 0], y_pred[:, 0])
print('The mae is: %.4f MPa' %mae_qc)
mse_qc = mean_squared_error(y_test[:, 0], y_pred[:, 0])
print('The mse is: %.4f MPa' %mse_qc)
rmse_qc = np.sqrt(mse).mean()
print('The rmse is: %.4f MPa' %rmse_qc)
r2_qc = r2_score(y_test[:, 0], y_pred[:, 0])
print('The R2 is: %.4f MPa' %r2_qc)

print('____________________________________________')

#Metrics for the fs
print('Metrics for fs')
mae_fs = mean_absolute_error(y_test[:, 1], y_pred[:, 1])
print('The mae is: %.4f kPa' %mae_fs)
mse_fs = mean_squared_error(y_test[:, 1], y_pred[:, 1])
print('The mse is: %.4f kPa' %mse_fs)
rmse_fs = np.sqrt(mse).mean()
print('The rmse is: %.4f kPa' %rmse_fs)
r2_fs= r2_score(y_test[:, 1], y_pred[:, 1])
print('The R2 is: %.4f kPa' %r2_fs)
# Out:
# Metrics Global
# The mae is: 19.4342
# The mse is: 1790.4860
# The rmse is: 42.3141
# The R2 is: 0.5197
# ____________________________________________
# Metrics for qc
# The mae is: 1.9203 MPa
# The mse is: 16.0169 MPa
# The rmse is: 42.3141 MPa
# The R2 is: 0.7583 MPa
# ____________________________________________
# Metrics for fs
# The mae is: 36.9481 kPa
# The mse is: 3564.9550 kPa
# The rmse is: 42.3141 kPa
# The R2 is: 0.2812 kPa

# %%
#History
from google.colab import files
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
ax = plt.gca()
#ax.set_ylim([0, 0.05])
plt.savefig('Fig_DNN_CPPTNet_01.png', dpi = 600)
#files.download("Fig_DNN_CPPTNet_01.png")
plt.show()
