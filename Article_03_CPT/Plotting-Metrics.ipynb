# %%
#General Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Mae Metrics for qc
df_metrics_mae_qc = pd.DataFrame({'mae_model':['model 01', 'model 02', 'model 03', 'model 04',
                              'model 05', 'model 06'], 'qc rf': [0.8026, 0.8578, 1.355, 1.7153, 1.9265, 1.4298], 
                   'qc_DNN': [1.4201, 1.4288, 1.6543, 1.7457, 1.9291, 1.5099]})

labels = ['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06']
qc_Rf = [0.8026, 0.8578, 1.355, 1.7153, 1.9265, 1.4298]
qc_DNN = [1.4201, 1.4288, 1.6543, 1.7457, 1.9291, 1.5099]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, qc_Rf, width, label = 'RF-qc', color = 'mediumorchid')
rects2 = ax.bar(x + width/2, qc_DNN, width, label = 'DNN-qc', color = 'blue')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mae for qc (MPa)')
#ax.set_xlabel('Model')
#ax.set_title('Mae (MPa) by Random Forest and DNN - qc')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which='major', labelsize=8)
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.savefig('Mae (MPa) by Random Forest and DNN - qc', dpi = 600)
plt.show()

# %%
#Mae Metrics for fs
df_metrics_mae_fs = pd.DataFrame({'mae_model':['model 01', 'model 02', 'model 03', 'model 04',
                              'model 05', 'model 06'], 'fs rf': [12.3376, 13.6537, 21.9816, 30.0939, 36.1712, 24.5329], 
                   'fs_DNN': [24.9707, 25.3788, 29.5817, 30.1711, 35.0811, 26.4091]})

labels = ['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06']
fs_Rf = [12.3376, 13.6537, 21.9816, 30.0939, 36.1712, 24.5329]
fs_DNN = [24.9707, 25.3788, 29.5817, 30.1711, 35.0811, 26.4091]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, qc_Rf, width, label = 'fs RFRM', color = 'mediumorchid')
rects2 = ax.bar(x + width/2, qc_DNN, width, label = 'fs DLNN', color = 'blue')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mae for fs (kPa)')
#ax.set_xlabel('Model')
#ax.set_title('Mae (kPa) by Random Forest and DNN - fs')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which='major', labelsize=8)
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.savefig('Mae (kPa) by Random Forest and DNN - fs', dpi = 600)
plt.show()

# %%
#Mse Metrics for qc
df_metrics_mse_qc = pd.DataFrame({'mse_model':['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06'], 
                                  'qc rf': [5.2134, 5.6282, 10.2466, 14.5052, 16.1387, 12.6335], 'qc DNN': [10.5825, 10.9622, 12.3141, 14.7304, 16.4847, 12.5370]})

labels = ['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06']
qc_Rf = [5.2134, 5.6282, 10.2466, 14.5052, 16.1387, 12.6335]
qc_DNN = [10.5825, 10.9622, 12.3141, 14.7304, 16.4847, 12.5370]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, qc_Rf, width, label = 'qc RF', color = 'mediumorchid')
rects2 = ax.bar(x + width/2, qc_DNN, width, label = 'qc DNN', color = 'blue')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mse for qc (MPa)')
#ax.set_xlabel('Model')
ax.set_title('Mse (MPa) by Random Forest and DNN - qc')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which='major', labelsize=8)
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.savefig('Mse (MPa) by Random Forest and DNN - qc', dpi = 600)
plt.show()

# %%
#Mse Metrics for fs
df_metrics_mse_fs = pd.DataFrame({'mse_model':['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06'], 
                                  'fs rf': [819.9637, 889.191, 1709.263, 2973.0461, 3580.881, 2382.8904], 'fs DNN': [2134.8128, 2194.7752, 2565.5604, 3036.1315, 3621.7455, 2402.9410]})

labels = ['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06']
qc_Rf = [819.9637, 889.191, 1709.263, 2973.0461, 3580.881, 2382.8904]
qc_DNN = [2134.8128, 2194.7752, 2565.5604, 3036.1315, 3621.7455, 2402.9410]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, qc_Rf, width, label = 'qc RF', color = 'mediumorchid')
rects2 = ax.bar(x + width/2, qc_DNN, width, label = 'qc DNN', color = 'blue')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mse for fs (kPa)')
#ax.set_xlabel('Model')
ax.set_title('Mse (kPa) by Random Forest and DNN - fs')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which='major', labelsize=8)
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.savefig('Mse (kPa) by Random Forest and DNN - fs', dpi = 600)
plt.show()

# %%
'''
Real rmse
qc
RF[2.2832, 2.3723, 3.2010, 3.8085, 4.0173]
DNN[3.2530, 3.3109, 3.5091, 3.8380, 4.0601]

fs
RF[28.6350, 29.8193, 41.3432, 54.5265, 59.87046]
DNN[56.2043, 46.8484, 50.65136, 55.1011, 60.1809]

'''
#Rmse Metrics for qc
df_metrics_rmse_qc = pd.DataFrame({'rmse_model':['model 01', 'model 02', 'model 03', 'model 04',
                              'model 05', 'model 06'], 'qc rf': [2.2832, 2.3723, 3.2010, 3.8085, 4.0173, 3.46087], 
                   'qc_DNN': [3.2530, 3.3109, 3.5091, 3.8380, 4.0601, 3.47525]})

labels = ['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06']
qc_Rf = [2.2832, 2.3723, 3.2010, 3.8085, 4.0173, 3.46087]
qc_DNN = [3.2530, 3.3109, 3.5091, 3.8380, 4.0601, 3.47525]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, qc_Rf, width, label = 'qc RF', color = 'mediumorchid')
rects2 = ax.bar(x + width/2, qc_DNN, width, label = 'qc DNN', color = 'blue')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('rmse for qc (MPa)')
#ax.set_xlabel('Model')
ax.set_title('Rmse (MPa) by Random Forest and DNN - qc')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which='major', labelsize=8)
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.savefig('Rmse (MPa) by Random Forest and DNN - qc', dpi = 600)
plt.show()

# %%
#Rmse Metrics for fs
df_metrics_rmse_fs = pd.DataFrame({'rmse_model':['model 01', 'model 02', 'model 03', 'model 04',
                              'model 05', 'model 06'], 'fs rf': [28.6350, 29.8193, 41.3432, 54.5265, 59.87046, 34.6087], 
                   'fs DNN': [56.2043, 46.8484, 50.65136, 55.1011, 60.1809, 34.7525]})

labels = ['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06']
fs_Rf = [28.6350, 29.8193, 41.3432, 54.5265, 59.87046, 34.6087]
fs_DNN = [56.2043, 46.8484, 50.65136, 55.1011, 60.1809, 34.7525]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, fs_Rf, width, label = 'qc RF', color = 'mediumorchid')
rects2 = ax.bar(x + width/2, fs_DNN, width, label = 'qc DNN', color = 'blue')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('rmse for fs (kPa)')
#ax.set_xlabel('Model')
ax.set_title('Rmse (kPa) by Random Forest and DNN - fs')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which='major', labelsize=8)
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.savefig('Rmse (kPa) by Random Forest and DNN - fs', dpi = 600)
plt.show()

# %%
#R2 Metrics for qc
df_metrics_r2 = pd.DataFrame({'r2_model':['model 01', 'model 02', 'model 03', 'model 04',
                              'model 05', 'model 06'], 'qc rf': [0.9327, 0.9155, 0.8474, 0.7842, 0.7587, 0.8131], 
                              'qc_DNN': [0.844, 0.8372, 0.8166, 0.7841, 0.7579, 0.8113]})

labels = ['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06']
qc_Rf = [0.9327, 0.9155, 0.8474, 0.7842, 0.7587, 0.8131]
qc_DNN = [0.844, 0.8372, 0.8166, 0.7841, 0.7579, 0.8113]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, qc_Rf, width, label = 'RF-qc', color = 'mediumorchid')
rects2 = ax.bar(x + width/2, qc_DNN, width, label = 'DNN-qc', color = 'blue')

# Add some text for labels, title and custom x-axis tick labels, etc.
start, end = ax.get_ylim() #ticks' frequency
ax.set_ylabel('$R^2$ for $q_c$', fontsize=12)
#ax.set_xlabel('Model')
#ax.set_title('r2 by Random Forest and DNN - qc')
# ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which='major', labelsize=12)
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.yaxis.set_ticks(np.arange(start, end, 0.10))
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.savefig('r2 by Random Forest and DNN - qc', dpi = 600)
plt.show()

# %%
#R2 Metrics for fs
df_metrics_r2 = pd.DataFrame({'r2_model':['model 01', 'model 02', 'model 03', 'model 04',
                              'model 05', 'model 06'], 'fs rf': [0.8787, 0.8228, 0.662, 0.4068, 0.2818, 0.5305], 
                   'fs DNN': [0.5778, 0.567, 0.497, 0.4036, 0.2906, 0.5201]})

labels = ['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06']
fs_Rf = [0.8787, 0.8228, 0.662, 0.4068, 0.2818, 0.5305]
fs_DNN = [0.5778, 0.567, 0.497, 0.4036, 0.2906, 0.5201]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, fs_Rf, width, label = 'RF-fs', color = 'mediumorchid')
rects2 = ax.bar(x + width/2, fs_DNN, width, label = 'DNN-fs', color = 'blue')

# Add some text for labels, title and custom x-axis tick labels, etc.
start, end = ax.get_ylim() #ticks' frequency
ax.set_ylabel('$R^2$ for $f_s$', fontsize=12)
# ax.set_ylabel('r2 for fs')
#ax.set_xlabel('Model')
#ax.set_title('r2 by Random Forest and DNN - fs')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which='major', labelsize=12)
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.yaxis.set_ticks(np.arange(start, end, 0.10))
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.savefig('r2-RF-DNN-fs', dpi = 600)
plt.show()

# %% [markdown]
# _____________________________________________________________________________
# TIME PROCESSING
# _____________________________________________________________________________

# %%
#Time processing
df_time_processing = pd.DataFrame({'time_model':['model 01', 'model 02', 'model 03', 'model 04',
                              'model 05', 'model 06'], 'time processing RFRM': [17.30, 13.03, 5.07, 2.52, 1.41, 13.92], 
                   'time processing DLNN': [39.33, 15.09, 18.02, 29.46, 20.23, 68.19]})

labels = ['model 01', 'model 02', 'model 03', 'model 04', 'model 05', 'model 06']
time_processing_RFRM = [17.30, 13.03, 5.07, 2.52, 1.41, 13.92]
time_processing_DLNN = [39.33, 15.09, 18.02, 29.46, 20.23, 68.19]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, time_processing_RFRM, width, label = 'time processing RF-models', color = 'mediumorchid')
rects2 = ax.bar(x + width/2, time_processing_DLNN, width, label = 'time processing DNN-models', color = 'blue')

# Add some text for labels, title and custom x-axis tick labels, etc.
start, end = ax.get_ylim() #ticks' frequency
ax.set_ylabel('time (minutes)')
#ax.set_xlabel('Model')
#ax.set_title('r2 by Random Forest and DNN - fs')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which='major', labelsize=8)
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.yaxis.set_ticks(np.arange(start, end, 5))
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.savefig('time-processing-RFRM-DLNN', dpi = 600)
plt.show()
